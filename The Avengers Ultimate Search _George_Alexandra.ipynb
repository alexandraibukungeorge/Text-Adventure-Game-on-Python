# %% [markdown]
# Hello there!
#
# Welcome to my Text Adventure Game. The Avengers Ultimate Search!
#
# The Avengers Ultimate Search draws its inspiration from Marvel’s “Avengers: Infinity War”
# (Wikipedia, The Free Encyclopedia, 2023) which was influenced largely by Jim Starlin’s 1992 limited edition comic series book “The Infinity Gauntlet” (Starlin, 2023) and a Marvel comic and movies like “Avengers: Endgame” (Wkipedia, The Free Encyclopedia, 2023).
#
# You have just been recruited by Nick Fury to join the Avengers! Your superpower is the ability to copy and adapt any super-human ability you encounter as your own through your gene mutation. You will get superpower options given to you on each mission.
#
# Your mission should you choose to accept is to go on different missions on three different planets, find Thanos and secure three of the five infinity rings (Mind, Soul and Time). Spiderman has secured three of the six rings... You are to secure the three infinity rings and report back to base.
#
# You will be guided by J.A.R.V.I.S (Tony Stark AI). Hope you survive his jokes and games.
#
# Good luck Agent. The world is counting you!!!
#
#
# References
#
# Starlin, J. (2023, January 16). The Infinity Gauntlet. Retrieved from Wikipedia, The Free Encyclopedia: https://en.wikipedia.org/wiki/The_Infinity_Gauntlet
# Wikipedia, The Free Encyclopedia. (2023, January 28). Avengers: Inifinity War. Retrieved from Wikipedia, The Free Encyclopedia: https://en.wikipedia.org/wiki/Avengers:_Infinity_War

# %%
# Import needed packages

import random
from random import randrange

# input username
user_name = input(prompt = '\nWelcome! Please input your name: \n')
user_name = user_name.capitalize() # Nullifying case sensitivity in player's response

adult_or_not = False # Check player is an adult or not
while True:
    age_input = input(prompt='\nHow old are you? Please input the number.\n') # Get age from player for verification

    try:
        age_input = int(age_input) # convert to integer
    except: # if not a number. 
        print(f'\nPlease input your age in number.\n')
        continue # Go back to while
    if 110 > age_input >= 18: # Verify age
        print(f'\nPlease go ahead!\n')
        adult_or_not = True
        break
    elif age_input >= 110:
        print(f'\nAre you still alive?!\n') # Are you kidding me?
    else:
        print(f'\nThis game is R rated. Sorry about that !') # Kids 
        break

# Mission 1 - The quest to find the 1st ring starts here
def Mission_1():
        
    print(f"""\nWelcome Agent {user_name} to the Avengers Ultimate Search!\n
    Your mission should you choose to accept is to find Thanos and secure three of the infinity rings.
    """)
    input(prompt = '<Press enter to continue>\n')
    
    # Quick mission update for the player
    print(f"""You are on Planet Aries. Find Thanos and retrieve the Mind ring
    Are you ready Avenger?\n
    Then...let's get right to it!\n""")
    input(prompt = '<Press enter to continue>\n')
    
    # Here the player picks from a list of Avengers provided, and J.A.R,V.I.S runs 3 random selection in the backgrd
    # I was able to introduce for loop with a very savvy random
    # I hope you give more marks Prof. I have really improved. lol
    avengers_list = ['Iron Man', 'Capt. America', 'Black Widow', 'Dr. Strange', 'Thor', 'Hulk', 'HawkEye', 
                 'Nick Fury', 'Capt. Marvel', 'Groot', 'Ant Man', 'Black Panther', 'Loki', 'Scarlet Witch', 
                 'War Machine', 'Vision', 'Falcon']

    random_names = random.sample(avengers_list, 3)

    for avenger in avengers_list:
        print(avenger)
        
    q1 = input(prompt='\nChoose your Avenger power to find the Mind ring (by any name):\t\n')

    # Conditional statement for Mission 1
    # Another stylish use of in, for loop... all in one buffet
    found_avenger = None
    for name in avengers_list:
        if q1.lower() in name.lower():
            found_avenger = name
            break

    if found_avenger:
        if found_avenger in random_names:
            print(f"Nicely done! You found {found_avenger}. You've bagged your first ring!")
            Mission_2()
            
        else:
            print(f"\nOops! You found {found_avenger}, but was not one of the randomly selected Avengers:")
            print (f"{random_names}.")
            print (f" Better luck next time!")
            Mission_1()
    else:
        print(f"\nError! {q1.capitalize()} is not a valid Avenger name.")
        Mission_1()


# Mission 2 - The quest to find the 2nd ring starts here. Its a random game in-between mission
# Players are not exepcted to win here to proceed. Just participate.

def Mission_2():

    print(f"""\nWelcome Agent {user_name} to Planet Prime!\n
    Your quest for the Soul ring starts here\n
    Do you wish to continue Agent {user_name}?\n""")
    input(prompt = '\n<Press enter to confirm>\n')
        
    avengers_list = ['Iron Man', 'Capt. America', 'Black Widow', 'Dr. Strange', 'Thor', 'Hulk', 'HawkEye', 
                              'Nick Fury', 'Capt. Marvel', 'Groot', 'HawkEye', 'Ant Man', 'Black Panther', 'Loki', 'Scarlet Witch', 
                              'Nebula', 'Rocket', 'War Machine', 'Vision', 'Falcon', 'Wasp', 'Okoye' ]

    
# This part of the of the mission is simply a conversation between J.A.R.V.I.S and the player.
# It has been incorporated into the game 
# This is them just making small talks in-between missions to bond.
# Player is to randomly make a selection and the game randomly chooses from the list
    
    mission_2 = input(prompt = f"""\nYou get to pick any Avenger for this mission
    You pick wrong...You lose!
    \nChoose an Avenger :   """)
    i = randrange(len(avengers_list))
    item = avengers_list[i]

    print(f"\nUndefeated Avenger is", avengers_list[i])        
    
    print(f"""\nJoke's on you! hahaha...See you around buddy!""")
    input(prompt = "\n<Press enter to proceed to the next round>\n")
    Mission_3()

# Mission 3 - The quest to find the final ring starts here

def Mission_3():

    # A quick trivia before player departs for mission
    # A fun way to allow the player name the planet (Cool right Prof.?!)
    
    planet = input('\nCan you guess the name of this planet?\n')
    planet = planet.capitalize()

    # J.A.R.V.I.S briefs the player 
    
    print(f"""\n\n\nWelcome Agent {user_name} to Planet {planet}!\n
            Your quest for the Time ring starts here
            Do you wish to continue Agent {user_name}?\n""")
    input(prompt = '<Press enter to confirm>\n')
    
    list_1 = ['Iron Man', 'Capt. America', 'Black Widow', 'Dr. Strange', 'Thor', 'Hulk', 'Hawk Eye', 'Nick Fury']
    list_2 = ['Capt. Marvel', 'Groot', 'Ant Man', 'Black Panther', 'Loki', 'Scarlet Witch']
    list_3 = ['Nebula', 'Rocket', 'War Machine', 'Vision', 'Falcon', 'Wasp', 'Okoye' ]
    
    # This stage is really random to dram in the player to engage more.
    # Hint is provided to make it a tad easier.
    
    choice = input(prompt = f"""\n\nPick an Avenger power of your choice to find the Time ring\t
    Choose right, you win the game...
    Hint: Win is only possible with 1st class Avengers :\t""")
    choice = choice.capitalize()
        
    seqs = list_1, list_2, list_3

    lst = random.choice(random.choices(seqs, weights=map(len, seqs))[0])

    choice = choice.capitalize()
    
    Iron_Man = ["Iron", "Man", "I"]
    Capt_America = ["Capt.", "Capt", "Cap", "America", "Cap."]
    Black_Widow = ["Black", "Widow", "Bl", "W"]
    Dr_Strange = ["Dr.", "Dr", "Strange"]
    Hawk_Eye = ["Hawk", "Eye", "HawkEye", "H"]
    Nick_Fury = ["Nick", "Fury", "N", "F", "Nic"]
    Capt_Marvel = ["Capt.", "Capt", "Cap", "Marvel", "Marv", "M", "Cap Marvel" "Capt. Marvel", "Capt Marvel"]
    Black_Widow = ["Black", "Widow", "Bl", "W", "Black Widow"]
    Black_Panther = ["Black", "Panther", "Black Panther", "B"]
    Ant_Man = ["Ant", "Man", "An", "Ant Man"]
    Scarlet_Witch = ["Scarlet", "Witch", "S"]
    War_Machine = ["War", "Machine", "War Machine"]
    
    input(prompt = '\nPress enter to reveal!\n')
    
# Nested conditional statement for Mission 2
    if choice in list_1:
        print(f"Excellent Choice! A pioneer Avenger\nYou found the Time ring!\n")
        game_win()
    
    elif choice in Iron_Man:
        print(f"Excellent Choice! A pioneer Avenger\nYou found the Time ring!\n")
        game_win()
    
    elif choice in Capt_America:
        print(f"Excellent Choice! A pioneer Avenger\nYou found the Time ring!\n")
        game_win()
    
    elif choice in Black_Widow:
        print(f"Excellent Choice! A pioneer Avenger\nYou found the Time ring!\n")
        game_win()

    elif choice in Dr_Strange:
        print(f"Excellent Choice! A pioneer Avenger\nYou found the Time ring!\n")
        game_win()
    
    elif choice in Hawk_Eye:
        print(f"Excellent Choice! A pioneer Avenger\nYou found the Time ring!\n")
        game_win()
    
    elif choice in Nick_Fury:
        print(f"Excellent Choice! The Genius Avenger.\nYou found the Time ring!\n")
        game_win()

    elif choice in list_2:
        print(f"Oops! A strong Avenger but Sorry... You lost this round.")
        game_fail()
 
    elif choice in Capt_Marvel:
        print(f"Oops! A strong Avenger but Sorry... You lost this round.")
        game_fail()

    elif choice in Black_Panther:
        print(f"Oops! A strong Avenger but Sorry... You lost this round.")
        game_fail()
    
    elif choice in Ant_Man:
        print(f"Oops! A strong Avenger but Sorry... You lost this round.")
        game_fail()

    elif choice in list_3:
        print(f"What?! You're kidding right ?! ")
        game_fail()

    elif choice in War_Machine:
        print(f"What?! You're kidding right ?! ")
        game_fail()
    
    else:
        print("\nCome back when you are ready to play!")
        game_fail()
     

# FAIL 
def game_fail():
    print(f"You're on your way to an alternate multiverse.\n")
    input(prompt = '<Press any key to exit>\n')


# WIN   
def game_win():
    print(f"""
    \nWOW! You're fantastic Agent {user_name}. You bagged your final ring. 
    YOU WIN!!!\n
    \nPlease report to the Avenger base with the infinty rings for post-mission debriefings.\n
    """)    
    input(prompt = '\n<Press any key to exit>\n')

# Call Mission 1
if adult_or_not:
    Mission_1()
else:
    game_fail()
    

## Hope you enjoyed playing##
# Out:
# Welcome! Please input your name:
# alex
#
# How old are you? Please input the number.
# 35
#
# Please go ahead!
#
#
# Welcome Agent Alex to the Avengers Ultimate Search!
#
#     Your mission should you choose to accept is to find Thanos and secure three of the infinity rings.
#
# <Press enter to continue>
#
# You are on Planet Aries. Find Thanos and retrieve the Mind ring
#     Are you ready Avenger?
#
#     Then...let's get right to it!
#
# <Press enter to continue>
#
# Iron Man
# Capt. America
# Black Widow
# Dr. Strange
# Thor
# Hulk
# HawkEye
# Nick Fury
# Capt. Marvel
# Groot
# Ant Man
# Black Panther
# Loki
# Scarlet Witch
# War Machine
# Vision
# Falcon
#
# Choose your Avenger power to find the Mind ring (by any name):
# falcon
#
# Oops! You found Falcon, but it was not one of the randomly selected Avengers:
# ['Capt. Marvel', 'Iron Man', 'Black Widow'].
#  Better luck next time!
#
# Welcome Agent Alex to the Avengers Ultimate Search!
#
# ...
